# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
students = pd.read_excel('Students09.xlsx')
students = students.sort_values(by= 'Number', ascending= False)
print(students)
# Out:
#                                 Field  Number
# 3                         Engineering  216932
# 1             Business and Management  200312
# 8     Other/Unspecified Subject Areas  185107
# 7   Mathematics and Computer Sciences  141651
# 10                    Social Sciences   81304
# 9          Physical and Life Sciences   75385
# 4               Fine and Applied Arts   59736
# 5                  Health Professions   33947
# 2                           Education   19483
# 6                          Humanities   17664
# 0                         Agriculture   12318

# %%
students.plot.bar(x= 'Field', y= 'Number', color= 'red', title= 'International Students by field')
#plt.tight_layout() #紧凑型
plt.show()

# %%
plt.bar(students.Field, students.Number, color= 'blue')
plt.xticks(students.Field, rotation = '90')
plt.xlabel('Field', fontsize = 13)
plt.ylabel('Number', fontsize= 13)
plt.title('International Students by field', fontsize = 15)
plt.show()

# %%
students = students.sort_values(by = 'Number', ascending= True)
students
# Out:
#                                 Field  Number
# 0                         Agriculture   12318
# 6                          Humanities   17664
# 2                           Education   19483
# 5                  Health Professions   33947
# 4               Fine and Applied Arts   59736
# 9          Physical and Life Sciences   75385
# 10                    Social Sciences   81304
# 7   Mathematics and Computer Sciences  141651
# 8     Other/Unspecified Subject Areas  185107
# 1             Business and Management  200312
# 3                         Engineering  216932

# %%
students.plot.bar(x ='Field', y= 'Number', color = 'red', title= 'Internationl Students by field')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#students.plot.bar(x ='Field', y= 'Number', color = 'red', title= 'Internationl Students by field')
plt.bar(students.Field, students.Number, color = 'orange')
plt.xticks(students.Field, rotation= '90')
plt.xlabel('Field', fontsize= 10)
plt.ylabel('Number', fontsize= 10)
plt.title('Internationl Students by field', fontsize= 15)

plt.show()
