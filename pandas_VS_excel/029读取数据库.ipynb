# %%
#方法一：用pyodbc连接SQL
import pandas as pd
import pyodbc

# %%
connection = pyodbc.connect('DRIVER={SQL Server}; SERVER=(local); DATABASE=AdventureWorks;USER=sa;PASSWORD=123456')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-2-70dab7f836fa> in <module>
# ----> 1 connection = pyodbc.connect('DRIVER={SQL Server}; SERVER=(local); DATABASE=AdventureWorks;USER=sa;PASSWORD=123456')
#
# Error: ('01000', "[01000] [unixODBC][Driver Manager]Can't open lib 'SQL Server' : file not found (0) (SQLDriverConnect)")

# %%
query = 'SELECT FirstName, LastName FROM Person.Person' #请求

# %%
df1 = pd.read_sql_query(query, connection)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-470e2317d45b> in <module>
# ----> 1 df1 = pd.read_sql_query(query, connection)
#
# NameError: name 'connection' is not defined

# %%
df1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-eda2b5cc1a42> in <module>
# ----> 1 df1.head()
#
# NameError: name 'df1' is not defined

# %%
#方法二：用sqlalchemy连接SQL
#SQLAlchemy是Python编程语言下的一款开源软件。提供了SQL工具包及对象关系映射工具，
#使用MIT许可证发行。 SQLAlchemy“采用简单的Python语言，为高效和高性能的数据库访问设计，实现了完整的企业级持久模型”

import sqlalchemy

# %%
engine = sqlalchemy.create_engine('mssql+pyodbc://sa:123456@(local)/AdventureWorks?driver=SQL+Server')

# %%
query = 'SELECT FirstName, LastName FROM Person.Person'

# %%
df2 = pd.read_sql_query(query, engine)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in connect(self)
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#
# ...

# %%
df2.head()
